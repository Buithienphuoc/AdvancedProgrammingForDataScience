# %% [markdown]
# # Assignment 2: Milestone I Natural Language Processing
# ## Task 2&3
# #### Student Name:
# Bui Thien Phuoc s3634831
# Nguyen Duc Anh
#
# Date: 23/08/2024
#
# Version: 1.0
#
# Environment: Python 3 and Jupyter notebook
#
# Libraries used: please include all the libraries you used in your assignment, e.g.,:
# * pandas
# * re
# * numpy
#
# ## Introduction
# You should give a brief information of this assessment task here.
#
# <span style="color: red"> Note that this is a sample notebook only. You will need to fill in the proper markdown and code blocks. You might also want to make necessary changes to the structure to meet your own needs. Note also that any generic comments written in this notebook are to be removed and replace with your own words.</span>

# %% [markdown]
# ## Importing libraries

# %%
# Code to import libraries as you need in this assessment, e.g.,
import numpy as np
import pandas as pd
import re
from collections import Counter

# %% [markdown]
# ## Task 2. Generating Feature Representations for Job Advertisement Descriptions

# %% [markdown]
# ...... Sections and code blocks on buidling different document feature represetations
#
#
# <span style="color: red"> You might have complex notebook structure in this section, please feel free to create your own notebook structure. </span>

# %%
# Code to perform the task...
df = pd.read_csv('data.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] # Drop the Unnamed column 'Index'
df
# Out:
#       ID                                  Title  Webindex  \
# 0    232                         fpa  blue chip  68802053
# 1    233        part time management accountant  70757636
# 2    234                          ifa  employed  71356489
# 3    235                        finance manager  69073629
# 4    236                  management accountant  70656648
# ..   ...                                    ...       ...
# 771  772                                 valuer  68056671
# 772  773            sales manager  it  telecoms  68256016
# 773  774                    telesales executive  71737507
# 774  775          international account manager  70205492
# 775  776  estate agency senior sales negotiator  72444142
#
#                          Company  \
# 0            hays senior finance
# 1                     fs2 uk ltd
# 2                clark james ltd
# 3         accountancy action ltd
# 4                alexander lloyd
# ..                           ...
# ...

# %%
vocab = {}
with open('vocab.txt', 'r') as f:
    for line in f:
        word, index = line.strip().split(':')
        vocab[word] = int(index)
print(vocab.get('abandonment'))
# Define the pattern for tokenization (same as used previously)

# Function to create a count vector for a single job description
def create_count_vector(tokenized_words):
    word_counts = Counter(tokenized_words)  # Count word frequencies
    # print(word_counts)
    return word_counts  # Return as a sparse vector string

# Apply the function to each row in the DataFrame and save to count_vectors.txt
with open('count_vectors.txt', 'w') as f:
    for index, description in df['Description'].iteritems():
        print(index, description)
        webindex = df.at[index, 'Webindex']  # Get the corresponding Webindex
        vector = dict(create_count_vector(description.split()))  # Convert Counter to a dictionary
        vector_str = ', '.join([f"{vocab.get(word)}:{count}" for word, count in vector.items() if vocab.get(word) is not None])
        f.write(f"#{webindex}, {{{vector_str}}}\n")
# Out:
# 5
# ...

# %% [markdown]
# ### Saving outputs
# Save the count vector representation as per spectification.
# - count_vectors.txt

# %%
# code to save output data...

# %% [markdown]
# ## Task 3. Job Advertisement Classification

# %% [markdown]
# ...... Sections and code blocks on buidling classification models based on different document feature represetations.
# Detailed comparsions and evaluations on different models to answer each question as per specification.
#
# <span style="color: red"> You might have complex notebook structure in this section, please feel free to create your own notebook structure. </span>

# %%
# Code to perform the task...

# %% [markdown]
# ## Summary
# Give a short summary and anything you would like to talk about the assessment tasks here.

# %% [markdown]
# ## Couple of notes for all code blocks in this notebook
# - please provide proper comment on your code
# - Please re-start and run all cells to make sure codes are runable and include your output in the submission.
# <span style="color: red"> This markdown block can be removed once the task is completed. </span>
